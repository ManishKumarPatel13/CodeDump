# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D, axes3d

# %% [markdown]
# # Surface plot

# %%
fig = plt.figure()
ax = plt.axes(projection = '3d')
x = np.arange(-2, 2, 0.1)
y = np.arange(-2, 2, 0.1)
xx, yy = np.meshgrid(x, y)
z = (1-yy**5 + xx**5)*np.exp(-xx**2-yy**2)
surf = ax.plot_surface(xx, yy, z, rstride=2, cstride=1)
ax.view_init(elev=30, azim=123) # This changes the initial position from which we start to see our plot
plt.show()

# %% [markdown]
# # WireFrame Plot

# %%
x= np.arange(1, 100, 1)
y= np.arange(1, 100, 1)
z= np.arange(1, 100, 1)
fig = plt.figure()
ax = plt.axes(projection='3d')
xi = np.linspace(x.min(), x.max(), 50)
yi = np.linspace(y.min(), y.max(), 50)
# zi = griddata((x, y), z, (xi[None, :], yi[:, None]), method='nearest')    # create a uniform spaced grid
xig, yig = np.meshgrid(xi, yi)
surf = ax.plot_wireframe(X=xig, Y=yig, Z=xig**2+yig**2, rstride=5, cstride=3, linewidth=1)   # 3d plot
plt.show()

# %% [markdown]
# # 3D Scatter Plot

# %%
# Create 3D data
x = np.random.rand(100)
y = np.random.rand(100)
z = np.random.rand(100)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot a 3D scatterplot of the data it can be 1d
ax.scatter3D(x, y, z, c='red')

# Set the title and labels
ax.set_title('3D Scatterplot')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Show the plot
plt.show()

# %% [markdown]
# # 3D Bar Plot

# %%
x = np.arange(8)
y = np.random.randint(0, 10, 8)
y2 = y + np.random.randint(0, 3, 8)
y3 = y2 + np.random.randint(0, 3, 8)
y4 = y3 + np.random.randint(0, 3, 8)
y5 = y4 + np.random.randint(0, 3, 8)


clr = ['r', 'b', 'g', 'y']
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.bar3d(x, y, 0, 0.5, 0.5, 1, color=clr[0])
ax.bar3d(x, y2,10 ,0.5, 0.5, 1, color=clr[1])
ax.bar3d(x, y3,20,0.5, 0.5, 1, color=clr[2])
ax.bar3d(x, y4,30,0.5, 0.5, 1, color=clr[3])
plt.show()

# %%
# Create a Figure and Axes3d object
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

# Create the 3D data for the plot
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
z = [3, 6, 9, 12, 15]

xx, yy = np.meshgrid(x, y)

# Plot the 3D bar plot
ax.bar3d(x, y, z, 0.5, 0.5, 1, color='blue')

# Set the axis labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Show the plot
plt.show()
