# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Axis
# xticks - labels on x axis<br>
# yticks - labels on y axis<br>
# xlim - x axis limit<br>
# ylim - y axis limit

# %%
x = np.arange(5)
y = np.random.randint(0, 5, 5)
plt.plot(x, y)

# plt.xticks(x, ["a", "b", "c", "d", "e"]) # change the xticks values according to x axis and name them according to the list passed
# plt.yticks(x) # Change y ticks
# plt.xlim(0, 10)
# plt.ylim(0, 10)

plt.axis([0,10, 0, 7]) #{{[x-axis start, x-axis end, y-axis start, y-axis end]}}

plt.show()
