# %%
import numpy as np
import matplotlib.pyplot as plt

tatti = np.array(["Anshu", "Vijay", "Vijaya", "Jaya", "Sanjay"])
tattikhana = np.array([5, 6, 5, 9, 4])
plt.bar(tatti, tattikhana)
# plt.xlabel("Tatti khayas")
# plt.ylabel("Tatti eating capacity")
plt.show()
